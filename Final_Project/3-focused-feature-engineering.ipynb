# %% [markdown]
# This file should run first to change the dataset from normal data into game difference data

# %%
# %matplotlib inline
import pandas as pd
import numpy as np
df = pd.read_csv('NBAPlayer_dataset.csv')

# %%
df.replace([np.inf, -np.inf], np.nan, inplace=True)

# %%
df.fillna(0, inplace=True)

# %%
df
# Out:
#            playDispNm  next_gmDays  pre_gmDays  gmTime  teamDayOff  playMin  \
# 0       Omari Johnson            1           2       3           1       16
# 1          Damion Lee            2           2       7           2       26
# 2          Damion Lee            2           2       7           1       32
# 3          Damion Lee            2           2       6           1       23
# 4          Damion Lee            2           1       7           1       23
# ...               ...          ...         ...     ...         ...      ...
# 154009     A.J. Price            4           1      19           1       11
# 154010     A.J. Price            1           4      13           2       14
# 154011     A.J. Price            3           1      21           1       10
# 154012     A.J. Price            2           3      22           3        4
# 154013     A.J. Price            3           2      22           2        4
#
#         playHeight  playWeight  playPTS  playAST  ...  opptDiv_Atlantic  \
# 0               81         220        5        1  ...                 0
# 1               78         210       14        1  ...                 0
# 2               78         210       20        1  ...                 1
# 3               78         210        4        2  ...                 0
# 4               78         210       15        1  ...                 0
# ...            ...         ...      ...      ...  ...               ...
# 154009          74         195        4        1  ...                 0
# 154010          74         195        6        3  ...                 0
# 154011          74         195        2        0  ...                 0
# 154012          74         195        0        0  ...                 0
# 154013          74         195        0        1  ...                 0
#
#         opptDiv_Central  opptDiv_Northwest  opptDiv_Pacific  \
# 0                     1                  0                0
# 1                     0                  0                0
# 2                     0                  0                0
# 3                     0                  0                0
# 4                     0                  0                0
# ...                 ...                ...              ...
# 154009                1                  0                0
# 154010                0                  0                0
# 154011                0                  0                0
# 154012                0                  0                1
# 154013                0                  1                0
#
#         opptDiv_Southeast  opptDiv_Southwest  age  Seats  Year_Open  \
# 0                       0                  0   31  18119       2004
# 1                       1                  0   35  18118       1999
# 2                       0                  0   36  18118       1999
# 3                       1                  0   38  18118       1999
# 4                       1                  0   26  18118       1999
# ...                   ...                ...  ...    ...        ...
# 154009                  0                  0   30  17500       2018
# 154010                  0                  1   26  19200       2001
# 154011                  0                  1   19  19200       2001
# 154012                  0                  0   28  17500       2016
# 154013                  0                  0   24  19441       1995
#
#         pre_gm_miles
# 0           0.000000
# 1         336.553712
# 2           0.000000
# 3           0.000000
# 4           0.000000
# ...              ...
# 154009    252.257751
# 154010    856.926415
# 154011      0.000000
# 154012   1439.908507
# 154013    483.505692
#
# [154014 rows x 86 columns]

# %%
select_num = list(df.drop(columns=['gmDayofyear','gmElapsed','pre_gm_miles','gmDayofweek','gmDay','teamDayOff','pre_gmDays','next_gmDays','playDispNm','teamConfIsEast','opptConfIsEast', 'teamRsltIsWin', 'opptRsltltIsWin', 'teamLocIsHome', 'opptLocIsHome', 'playPos_C', 'playPos_F', 'playPos_G', 'playPos_PF', 'playPos_PG', 'playPos_SF', 'playPos_SG', 'teamDiv_Atlantic', 'teamDiv_Central', 'teamDiv_Northwest', 'teamDiv_Pacific', 'teamDiv_Southeast', 'teamDiv_Southwest', 'opptDiv_Atlantic', 'opptDiv_Central', 'opptDiv_Northwest', 'opptDiv_Pacific', 'opptDiv_Southeast','opptDiv_Southwest']).columns.values.tolist())

# %%
df.shape
# Out:
# (154014, 86)

# %%
len(select_num)
# Out:
# 52

# %% [markdown]
# write a for loop for every player with almost every cols

# %%
playerlist = list(df['playDispNm'].unique())

# %%
# %%time
df_list=[]
df_final = pd.DataFrame()
for player in playerlist:
    df_diff = df[df['playDispNm'] == player][select_num].diff()
    df_diff = df_diff.add_suffix('_diff')
    df_new = df[df['playDispNm'] == player].join(df_diff, how='outer')
    df_list.append(df_new)
# Out:
# CPU times: user 13.9 s, sys: 145 ms, total: 14 s
# Wall time: 14.1 s

# %% [markdown]
# And now, we could have the NBA Player per game data transformed into difference from last game which would be more useful to predict would player increase or decrease his play minute in next game

# %%
df_new_diff = pd.concat(df_list)

# %%
df_new_diff.describe(include='all')
# Out:
#           playDispNm    next_gmDays     pre_gmDays         gmTime  \
# count         154014  154014.000000  154014.000000  154014.000000
# unique           895            NaN            NaN            NaN
# top     Corey Brewer            NaN            NaN            NaN
# freq             482            NaN            NaN            NaN
# mean             NaN       2.349851       2.390562      15.682535
# std              NaN       1.277117       1.296341       5.880749
# min              NaN       0.000000       0.000000       1.000000
# 25%              NaN       2.000000       2.000000       9.000000
# 50%              NaN       2.000000       2.000000      19.000000
# 75%              NaN       3.000000       3.000000      20.000000
# max              NaN       9.000000       9.000000      22.000000
#
#            teamDayOff        playMin     playHeight     playWeight  \
# count   154014.000000  154014.000000  154014.000000  154014.000000
# unique            NaN            NaN            NaN            NaN
# top               NaN            NaN            NaN            NaN
# freq              NaN            NaN            NaN            NaN
# mean         2.076396      22.988676      79.011609     217.932941
# std          1.049777      10.690116       3.431578      25.942307
# min          0.000000       0.000000      69.000000     149.000000
# 25%          2.000000      15.000000      77.000000     200.000000
# 50%          2.000000      24.000000      79.000000     220.000000
# 75%          2.000000      31.000000      82.000000     237.000000
# max         11.000000      60.000000      87.000000     290.000000
#
#               playPTS        playAST  ...  playBIs_month_start_diff  \
# count   154014.000000  154014.000000  ...                  153119.0
# unique            NaN            NaN  ...                       NaN
# top               NaN            NaN  ...                       NaN
# freq              NaN            NaN  ...                       NaN
# mean         9.855974       2.185892  ...                       0.0
# std          7.932366       2.532465  ...                       0.0
# min          0.000000       0.000000  ...                       0.0
# 25%          4.000000       0.000000  ...                       0.0
# 50%          8.000000       1.000000  ...                       0.0
# 75%         15.000000       3.000000  ...                       0.0
# max         62.000000      25.000000  ...                       0.0
#
#         playBIs_quarter_end_diff  playBIs_quarter_start_diff  \
# count              153119.000000                    153119.0
# unique                       NaN                         NaN
# top                          NaN                         NaN
# freq                         NaN                         NaN
# mean                    0.000007                         0.0
# std                     0.004426                         0.0
# min                    -1.000000                         0.0
# 25%                     0.000000                         0.0
# 50%                     0.000000                         0.0
# 75%                     0.000000                         0.0
# max                     1.000000                         0.0
#
#         playBIs_year_end_diff  playBIs_year_start_diff  playBElapsed_diff  \
# count                153119.0                 153119.0       1.531190e+05
# unique                    NaN                      NaN                NaN
# top                       NaN                      NaN                NaN
# freq                      NaN                      NaN                NaN
# mean                      0.0                      0.0       5.365615e+03
# std                       0.0                      0.0       3.295159e+06
# min                       0.0                      0.0      -4.782240e+08
# 25%                       0.0                      0.0       0.000000e+00
# 50%                       0.0                      0.0       0.000000e+00
# 75%                       0.0                      0.0       0.000000e+00
# max                       0.0                      0.0       4.782240e+08
#
#         IsStarter_diff       age_diff     Seats_diff  Year_Open_diff
# count    153119.000000  153119.000000  153119.000000   153119.000000
# unique             NaN            NaN            NaN             NaN
# top                NaN            NaN            NaN             NaN
# freq               NaN            NaN            NaN             NaN
# mean          0.000300       0.017019      -0.065753       -0.006217
# std           0.278099       5.665299    1046.396279       11.421597
# min          -1.000000     -22.000000   -4050.000000      -52.000000
# 25%           0.000000      -4.000000     -13.000000        0.000000
# 50%           0.000000       0.000000       0.000000        0.000000
# 75%           0.000000       4.000000       7.000000        0.000000
# max           1.000000      21.000000    4050.000000       52.000000
#
# [11 rows x 138 columns]

# %%
df_new_diff.shape
# Out:
# (154014, 138)

# %%
df_new_diff.drop(columns=select_num, inplace=True)

# %%
df_new_diff.fillna(0, inplace=True)

# %%
df_new_diff.to_csv('2012-18_playerBoxScore_diff.csv')
