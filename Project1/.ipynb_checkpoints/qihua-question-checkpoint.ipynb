# %%
import pandas as pd

# %%
df = pd.read_csv('cleaned_playerbox.csv')

# %%
date_array = df[df['playDispNm'] == 'Trevor Ariza'].gmDate.to_frame()

# %%
date_array.head()
# Out:
#         gmDate
# 1     10/30/12
# 542    11/3/12
# 1175   11/7/12
# 1442   11/9/12
# 1728  11/10/12

# %%
date_array.reset_index(inplace=True)
date_array.drop(columns='index').head()
# Out:
#      level_0    gmDate
# 0          0  10/30/12
# 1          1   11/3/12
# 2          2   11/7/12
# 3          3   11/9/12
# 4          4  11/10/12
# ..       ...       ...
# 438      438   3/30/18
# 439      439    4/1/18
# 440      440    4/5/18
# 441      441    4/7/18
# 442      442   4/10/18
#
# [443 rows x 2 columns]

# %%
second_series = pd.Series(date_array, name = 'second')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-6-52cd41073825> in <module>
# ----> 1 second_series = pd.Series(date_array, name = 'second')
#
# ~/anaconda3/lib/python3.7/site-packages/pandas/core/series.py in __init__(self, data, index, dtype, name, copy, fastpath)
#     311                 data = sanitize_array(data, index, dtype, copy, raise_cast_failure=True)
#     312
# --> 313                 data = SingleBlockManager(data, index, fastpath=True)
#     314
#     315         generic.NDFrame.__init__(self, data, fastpath=True)
#
# ~/anaconda3/lib/python3.7/site-packages/pandas/core/internals/managers.py in __init__(self, block, axis, do_integrity_check, fastpath)
#    1513
#    1514         if not isinstance(block, Block):
# -> 1515             block = make_block(block, placement=slice(0, len(axis)), ndim=1)
#    1516
# ...

# %%
idx = list(range(1, 444))

# %%
first_series = pd.Series(date_array, index = idx, name = 'first')

# %%
pd.merge(first_series, second_series, left_index=True, right_index=True)
